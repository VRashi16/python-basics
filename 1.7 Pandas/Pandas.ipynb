# %% [markdown]
# Pandas is one of the most popular Python libraries for Data Science and Analytics.
#
# Because pandas helps you to manage two-dimensional data tables in Python. Of course, it has many more features.

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ## Pandas data structures

# %% [markdown]
# There are two types of data structures in pandas: Series and DataFrames.

# %% [markdown]
# ### Series

# %% [markdown]
# A pandas Series is a one dimensional data structure (“a one dimensional ndarray”) that can store values — and for every value it holds a unique index, too.

# %% [markdown]
# ### DataFrame

# %% [markdown]
# a pandas DataFrame is a two (or more) dimensional data structure – basically a table with rows and columns. The columns have names and the rows have indexes.

# %% [markdown]
# ## Loading a .csv file into a pandas DataFrame

# %% [markdown]
# There is a function for it, called read_csv().

# %% [markdown]
# ## Selecting data from a dataframe in pandas

# %% [markdown]
# ### Print the whole dataframe

# %%
data = pd.read_csv('data.csv', skiprows=4)
data
# Out:
#           City  Edition      Sport       Discipline  \
# 0       Athens     1896   Aquatics         Swimming
# 1       Athens     1896   Aquatics         Swimming
# 2       Athens     1896   Aquatics         Swimming
# 3       Athens     1896   Aquatics         Swimming
# 4       Athens     1896   Aquatics         Swimming
# 5       Athens     1896   Aquatics         Swimming
# 6       Athens     1896   Aquatics         Swimming
# 7       Athens     1896   Aquatics         Swimming
# 8       Athens     1896   Aquatics         Swimming
# 9       Athens     1896   Aquatics         Swimming
# 10      Athens     1896   Aquatics         Swimming
# 11      Athens     1896  Athletics        Athletics
# 12      Athens     1896  Athletics        Athletics
# 13      Athens     1896  Athletics        Athletics
# 14      Athens     1896  Athletics        Athletics
# 15      Athens     1896  Athletics        Athletics
# 16      Athens     1896  Athletics        Athletics
# ...

# %% [markdown]
# ### Print a sample of your dataframe

# %% [markdown]
# Sometimes, it’s handy not to print the whole dataframe and flood your screen with data. When a few lines is enough, you can print only the first 5 lines – by typing:

# %%
data.head()
# Out:
#      City  Edition     Sport Discipline             Athlete  NOC Gender  \
# 0  Athens     1896  Aquatics   Swimming       HAJOS, Alfred  HUN    Men
# 1  Athens     1896  Aquatics   Swimming    HERSCHMANN, Otto  AUT    Men
# 2  Athens     1896  Aquatics   Swimming   DRIVAS, Dimitrios  GRE    Men
# 3  Athens     1896  Aquatics   Swimming  MALOKINIS, Ioannis  GRE    Men
# 4  Athens     1896  Aquatics   Swimming  CHASAPIS, Spiridon  GRE    Men
#
#                         Event Event_gender   Medal
# 0              100m freestyle            M    Gold
# 1              100m freestyle            M  Silver
# 2  100m freestyle for sailors            M  Bronze
# 3  100m freestyle for sailors            M    Gold
# 4  100m freestyle for sailors            M  Silver

# %% [markdown]
# Or the last few lines by typing:

# %%
data.tail()
# Out:
#           City  Edition      Sport       Discipline               Athlete  \
# 29211  Beijing     2008  Wrestling  Wrestling Gre-R        ENGLICH, Mirko
# 29212  Beijing     2008  Wrestling  Wrestling Gre-R  MIZGAITIS, Mindaugas
# 29213  Beijing     2008  Wrestling  Wrestling Gre-R       PATRIKEEV, Yuri
# 29214  Beijing     2008  Wrestling  Wrestling Gre-R         LOPEZ, Mijain
# 29215  Beijing     2008  Wrestling  Wrestling Gre-R        BAROEV, Khasan
#
#        NOC Gender       Event Event_gender   Medal
# 29211  GER    Men   84 - 96kg            M  Silver
# 29212  LTU    Men  96 - 120kg            M  Bronze
# 29213  ARM    Men  96 - 120kg            M  Bronze
# 29214  CUB    Men  96 - 120kg            M    Gold
# 29215  RUS    Men  96 - 120kg            M  Silver

# %% [markdown]
# Or a few random lines by typing:

# %%
data.sample(10)
# Out:
#               City  Edition       Sport       Discipline  \
# 19362        Seoul     1988    Shooting         Shooting
# 20863    Barcelona     1992      Rowing           Rowing
# 20632    Barcelona     1992    Handball         Handball
# 12128       Mexico     1968     Cycling     Cycling Road
# 24565       Sydney     2000      Hockey           Hockey
# 752       St Louis     1904   Athletics        Athletics
# 14469     Montreal     1976     Fencing          Fencing
# 12172       Mexico     1968  Equestrian         Eventing
# 17182  Los Angeles     1984  Equestrian         Dressage
# 23400       Sydney     2000    Aquatics  Synchronized S.
#
#                         Athlete  NOC Gender                     Event  \
# 19362           SPERBER, Silvia  FRG  Women  10m air rifle (40 shots)
# 20863      ETTINGSHAUSEN, Colin  GER    Men         coxless pair (2-)
# 20632               HAJAS, Erik  SWE    Men                  handball
# ...

# %% [markdown]
# ### Select specific columns of your dataframe

# %% [markdown]
# This one is a bit tricky! Let’s say you want to print the ‘City’ and the ‘Medal’ columns only.
# You should use this syntax:

# %%
data[['City','Medal']]
# Out:
#           City   Medal
# 0       Athens    Gold
# 1       Athens  Silver
# 2       Athens  Bronze
# 3       Athens    Gold
# 4       Athens  Silver
# 5       Athens  Bronze
# 6       Athens    Gold
# 7       Athens  Silver
# 8       Athens  Bronze
# 9       Athens    Gold
# 10      Athens  Silver
# 11      Athens  Bronze
# 12      Athens  Bronze
# 13      Athens    Gold
# 14      Athens  Silver
# 15      Athens    Gold
# 16      Athens  Silver
# 17      Athens  Bronze
# 18      Athens    Gold
# 19      Athens  Silver
# 20      Athens  Bronze
# 21      Athens    Gold
# 22      Athens  Silver
# 23      Athens  Bronze
# 24      Athens    Gold
# 25      Athens  Silver
# 26      Athens  Bronze
# 27      Athens    Gold
# 28      Athens  Silver
# 29      Athens    Gold
# ...        ...     ...
# 29186  Beijing  Bronze
# 29187  Beijing    Gold
# 29188  Beijing  Silver
# 29189  Beijing  Bronze
# 29190  Beijing  Bronze
# 29191  Beijing    Gold
# 29192  Beijing  Silver
# 29193  Beijing  Bronze
# ...

# %% [markdown]
# the outer bracket frames tell pandas that you want to select columns, and the inner brackets are for the list (remember? Python lists go between bracket frames) of the column names.

# %% [markdown]
# By the way, if you change the order of the column names, the order of the returned columns will change, too:

# %%
data[['Medal','City']]
# Out:
#         Medal     City
# 0        Gold   Athens
# 1      Silver   Athens
# 2      Bronze   Athens
# 3        Gold   Athens
# 4      Silver   Athens
# 5      Bronze   Athens
# 6        Gold   Athens
# 7      Silver   Athens
# 8      Bronze   Athens
# 9        Gold   Athens
# 10     Silver   Athens
# 11     Bronze   Athens
# 12     Bronze   Athens
# 13       Gold   Athens
# 14     Silver   Athens
# 15       Gold   Athens
# 16     Silver   Athens
# 17     Bronze   Athens
# 18       Gold   Athens
# 19     Silver   Athens
# 20     Bronze   Athens
# 21       Gold   Athens
# 22     Silver   Athens
# 23     Bronze   Athens
# 24       Gold   Athens
# 25     Silver   Athens
# 26     Bronze   Athens
# 27       Gold   Athens
# 28     Silver   Athens
# 29       Gold   Athens
# ...       ...      ...
# 29186  Bronze  Beijing
# 29187    Gold  Beijing
# 29188  Silver  Beijing
# 29189  Bronze  Beijing
# 29190  Bronze  Beijing
# 29191    Gold  Beijing
# 29192  Silver  Beijing
# 29193  Bronze  Beijing
# ...

# %% [markdown]
# This is the DataFrame of your selected columns.

# %%
data.City
# Out:
# 0         Athens
# 1         Athens
# 2         Athens
# 3         Athens
# 4         Athens
# 5         Athens
# 6         Athens
# 7         Athens
# 8         Athens
# 9         Athens
# 10        Athens
# 11        Athens
# 12        Athens
# 13        Athens
# 14        Athens
# 15        Athens
# 16        Athens
# 17        Athens
# 18        Athens
# 19        Athens
# 20        Athens
# 21        Athens
# 22        Athens
# 23        Athens
# 24        Athens
# 25        Athens
# 26        Athens
# 27        Athens
# 28        Athens
# 29        Athens
#           ...
# 29186    Beijing
# 29187    Beijing
# 29188    Beijing
# 29189    Beijing
# 29190    Beijing
# 29191    Beijing
# 29192    Beijing
# 29193    Beijing
# 29194    Beijing
# 29195    Beijing
# 29196    Beijing
# 29197    Beijing
# 29198    Beijing
# 29199    Beijing
# 29200    Beijing
# 29201    Beijing
# 29202    Beijing
# 29203    Beijing
# 29204    Beijing
# 29205    Beijing
# 29206    Beijing
# ...

# %% [markdown]
# Sometimes (especially in predictive analytics projects), you want to get Series objects instead of DataFrames.

# %% [markdown]
# ### Filter for specific values in your dataframe

# %% [markdown]
# Let’s say, you want to see a list of only the users who earned from the ‘Gold’ source. In this case you have to filter for the ‘Gold’ value in the ‘Medal’ column:

# %%
data[data.Medal == 'Gold']
# Out:
#           City  Edition          Sport       Discipline  \
# 0       Athens     1896       Aquatics         Swimming
# 3       Athens     1896       Aquatics         Swimming
# 6       Athens     1896       Aquatics         Swimming
# 9       Athens     1896       Aquatics         Swimming
# 13      Athens     1896      Athletics        Athletics
# 15      Athens     1896      Athletics        Athletics
# 18      Athens     1896      Athletics        Athletics
# 21      Athens     1896      Athletics        Athletics
# 24      Athens     1896      Athletics        Athletics
# 27      Athens     1896      Athletics        Athletics
# 29      Athens     1896      Athletics        Athletics
# 33      Athens     1896      Athletics        Athletics
# 36      Athens     1896      Athletics        Athletics
# 40      Athens     1896      Athletics        Athletics
# 43      Athens     1896      Athletics        Athletics
# 46      Athens     1896      Athletics        Athletics
# ...

# %%
data = pd.read_csv('data.csv', skiprows=4)
data
# Out:
#           City  Edition      Sport       Discipline  \
# 0       Athens     1896   Aquatics         Swimming
# 1       Athens     1896   Aquatics         Swimming
# 2       Athens     1896   Aquatics         Swimming
# 3       Athens     1896   Aquatics         Swimming
# 4       Athens     1896   Aquatics         Swimming
# 5       Athens     1896   Aquatics         Swimming
# 6       Athens     1896   Aquatics         Swimming
# 7       Athens     1896   Aquatics         Swimming
# 8       Athens     1896   Aquatics         Swimming
# 9       Athens     1896   Aquatics         Swimming
# 10      Athens     1896   Aquatics         Swimming
# 11      Athens     1896  Athletics        Athletics
# 12      Athens     1896  Athletics        Athletics
# 13      Athens     1896  Athletics        Athletics
# 14      Athens     1896  Athletics        Athletics
# 15      Athens     1896  Athletics        Athletics
# 16      Athens     1896  Athletics        Athletics
# ...

# %% [markdown]
# ### Basic Analysis of Dataset

# %% [markdown]
# pandas has several methods that allow you to quickly analyze a dataset and get an idea of the type and amount of data you are dealing with along with some important statistics.
#
# - .shape - returns the row and column count of a dataset
# - .describe() - returns statistics about the numerical columns in a dataset
# - .dtypes returns the data type of each column

# %%
data.shape
# Out:
# (29216, 10)

# %%
data.describe()
# Out:
#             Edition
# count  29216.000000
# mean    1967.713171
# std       32.406293
# min     1896.000000
# 25%     1948.000000
# 50%     1976.000000
# 75%     1996.000000
# max     2008.000000

# %% [markdown]
# Here are some additional methods that can give you statistics of a DataFrame or particular column in a DataFrame.
# - .mean(axis=0 [will give you the calculated value per column]) - returns the statistical mean
# - .median(axis=0 [will give you the calculated value per column]) - returns the statistical median
# - .mode(axis=0 [will give you the calculated value per column]) - returns the statistical mode
# - .count() - gives number of total values in column
# - .unique() - returns array of all unique values in that column
# - .value_counts() - returns object containing counts of unique values

# %%
data[data.Medal == 'Gold'].mean()
# Out:
# Edition    1966.510457
# dtype: float64

# %%
data[data.Medal == 'Gold'].median()
# Out:
# Edition    1976.0
# dtype: float64

# %%
data[data.Medal == 'Gold'].mode()
# Out:
#      City  Edition     Sport Discipline          Athlete  NOC Gender  \
# 0  Athens     2008  Aquatics  Athletics  PHELPS, Michael  USA    Men
#
#       Event Event_gender Medal
# 0  football            M  Gold

# %%
data[data.Medal == 'Gold'].count()
# Out:
# City            9850
# Edition         9850
# Sport           9850
# Discipline      9850
# Athlete         9850
# NOC             9850
# Gender          9850
# Event           9850
# Event_gender    9850
# Medal           9850
# dtype: int64

# %%
data[data.Medal == 'Gold'].count().unique()
# Out:
# array([9850], dtype=int64)

# %%
data[data.Medal == 'Gold'].count().value_counts()
# Out:
# 9850    10
# dtype: int64
